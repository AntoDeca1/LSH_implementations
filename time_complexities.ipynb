# %%
import matplotlib.pyplot as plt
import time
import numpy as np
from tqdm import tqdm
import big_o as big_o

# %%
def measure_time(func, args):
    start_time = time.time()
    # Execute the operation
    _ = func(*args) - 0.5
    end_time = time.time()
    return end_time - start_time

# %% [markdown]
# ## np.random.rand time complexities estimate

# %%
# Different sizes for testing
sizes = [(10, 10, 10), (100, 100, 100), (1000, 1000, 1000)]
trials = 50
times = []

# Measure time for each size
for size in sizes:
    temp_times = []
    for trial in tqdm(range(trials)):
        time_taken = measure_time(np.random.rand, size)
        temp_times.append(time_taken)
    times.append(np.mean(temp_times))

# Plotting the results
plt.plot([np.prod(size) for size in sizes], times, marker='o')
plt.xlabel('Total number of elements')
plt.ylabel('Time taken (seconds)')
plt.title('Time Complexity of np.random.rand - .5')
plt.grid(True)
plt.show()
# Out:
# ...
# 100%|██████████| 50/50 [06:31<00:00,  7.83s/it]

# %%
# Different sizes for testing
sizes = [(10, 10, 10), (100, 10, 10), (1000, 10, 10)]
trials = 100
times = []

# Measure time for each size
for size in sizes:
    temp_times = []
    for trial in tqdm(range(trials)):
        time_taken = measure_time(np.random.rand, size)
        temp_times.append(time_taken)
    times.append(np.mean(temp_times))

# Plotting the results
plt.plot([np.prod(size) for size in sizes], times, marker='o')
plt.xlabel('Total number of elements')
plt.ylabel('Time taken (seconds)')
plt.title('Time Complexity of np.random.rand - .5')
plt.grid(True)
plt.show()
# Out:
# ...
# 100%|██████████| 100/100 [00:00<00:00, 2619.44it/s]

# %%
# Different sizes for testing
sizes = [(10, 10, 10), (10, 100, 10), (10, 1000, 10)]
trials = 100
times = []

# Measure time for each size
for size in sizes:
    temp_times = []
    for trial in tqdm(range(trials)):
        time_taken = measure_time(np.random.rand, size)
        temp_times.append(time_taken)
    times.append(np.mean(temp_times))

# Plotting the results
plt.plot([np.prod(size) for size in sizes], times, marker='o')
plt.xlabel('Total number of elements')
plt.ylabel('Time taken (seconds)')
plt.title('Time Complexity of np.random.rand - .5')
plt.grid(True)
plt.show()
# Out:
# ...
# 100%|██████████| 100/100 [00:00<00:00, 2649.56it/s]

# %%
# Different sizes for testing
sizes = [(10, 10, 10), (10, 10, 100), (10, 10, 1000)]
trials = 50
times = []

# Measure time for each size
for size in sizes:
    temp_times = []
    for trial in tqdm(range(trials)):
        time_taken = measure_time(np.random.rand, size)
        temp_times.append(time_taken)
    times.append(np.mean(temp_times))

# Plotting the results
plt.plot([np.prod(size) for size in sizes], times, marker='o')
plt.xlabel('Total number of elements')
plt.ylabel('Time taken (seconds)')
plt.title('Time Complexity of np.random.rand - .5')
plt.grid(True)
plt.show()
# Out:
# ...
# 100%|██████████| 50/50 [00:00<00:00, 2307.00it/s]

# %% [markdown]
# ## numpy concatenate estimate

# %%
def measure_time(func, args):
    start_time = time.time()
    # Execute the operation
    _ = func(args)
    end_time = time.time()
    return end_time - start_time

# %%
def matrix_mask(matrix):
    output_matrix = (matrix > 0).astype(int)
    return output_matrix

# %%
matrices = [np.random.rand(10, 10, 10), np.random.rand(100, 100, 100), np.random.rand(200, 200, 200),
            np.random.rand(200, 200, 200), np.random.rand(300, 300, 300), np.random.rand(400, 400, 400),
            np.random.rand(500, 500, 500)]
trials = 100
times = []
for matrix in matrices:
    temp_times = []
    for trial in tqdm(range(trials)):
        time_taken = measure_time(matrix_mask, matrix)
        temp_times.append(time_taken)
    times.append(np.mean(temp_times))
# Out:
# ...
# 100%|██████████| 100/100 [00:13<00:00,  7.53it/s]

# %%
# Plotting the results
plt.plot([np.sum(matrix.shape) for matrix in matrices], times, marker='o')
plt.xlabel('Total number of elements')
plt.ylabel('Time taken (seconds)')
plt.title('Time Complexity of >0 + astype(int)')
plt.grid(True)
plt.show()

# %%
matrices = [np.random.rand(10, 10, 10), np.random.rand(100, 10, 10), np.random.rand(500, 10, 10),
            np.random.rand(1000, 10, 10), np.random.rand(1500, 10, 10)]
trials = 1500
times = []
for matrix in matrices:
    temp_times = []
    for trial in tqdm(range(trials)):
        time_taken = measure_time(matrix_mask, matrix)
        temp_times.append(time_taken)
    times.append(np.mean(temp_times))
# Out:
# ...
# 100%|██████████| 1500/1500 [00:00<00:00, 27958.92it/s]

# %%
# Plotting the results
plt.plot([np.sum(matrix.shape) for matrix in matrices], times, marker='o')
plt.xlabel('Total number of elements')
plt.ylabel('Time taken (seconds)')
plt.title('Time Complexity of >0 + astype(int)')
plt.grid(True)
plt.show()

# %%
matrices = [np.random.rand(10, 10, 10), np.random.rand(10, 100, 10), np.random.rand(10, 1000, 10),
            np.random.rand(10, 1500, 10), np.random.rand(10, 2000, 10), np.random.rand(10, 2500, 10),
            np.random.rand(10, 3000, 10)]
trials = 100
times = []
for matrix in matrices:
    temp_times = []
    for trial in tqdm(range(trials)):
        time_taken = measure_time(matrix_mask, matrix)
        temp_times.append(time_taken)
    times.append(np.mean(temp_times))
# Out:
# ...
# 100%|██████████| 100/100 [00:00<00:00, 5788.76it/s]

# %%
# Plotting the results
plt.plot([np.sum(matrix.shape) for matrix in matrices], times, marker='o')
plt.xlabel('Total number of elements')
plt.ylabel('Time taken (seconds)')
plt.title('Time Complexity of >0 + astype(int)')
plt.grid(True)
plt.show()

# %%
def measure_time(func, args):
    start_time = time.time()
    # Execute the operation
    _ = func(args, axis=0)
    end_time = time.time()
    return end_time - start_time

matrices = [np.random.rand(100, 100), np.random.rand(200, 200), np.random.rand(300, 300), np.random.rand(400, 400),np.random.rand(500, 500),np.random.rand(600, 600),np.random.rand(700, 700),np.random.rand(800, 800)]
trials = 2000
times = []
for matrix in matrices:
    temp_times = []
    for trial in tqdm(range(trials)):
        time_taken = measure_time(np.unique, matrix)
        temp_times.append(time_taken)
    times.append(np.mean(temp_times))
# Out:
# ...
# 100%|██████████| 2000/2000 [00:12<00:00, 157.68it/s]

# %%
# Plotting the results
plt.plot([np.sum(matrix.shape) for matrix in matrices], times, marker='o')
plt.xlabel('Total number of elements')
plt.ylabel('Time taken (seconds)')
plt.title('Time Complexity of >0 + astype(int)')
plt.grid(True)
plt.show()

# %%
def measure_time(func, args):
    start_time = time.time()
    # Execute the operation
    _ = func(args, axis=0)
    end_time = time.time()
    return end_time - start_time

matrices = [np.random.rand(10, 100), np.random.rand(10, 200), np.random.rand(10, 300), np.random.rand(10, 400),np.random.rand(10, 500),np.random.rand(10, 600),np.random.rand(10, 700),np.random.rand(10, 800),np.random.rand(10, 900)]
trials = 2000
times = []
for matrix in matrices:
    temp_times = []
    for trial in tqdm(range(trials)):
        time_taken = measure_time(np.unique, matrix)
        temp_times.append(time_taken)
    times.append(np.mean(temp_times))
# Out:
# ...
# 100%|██████████| 2000/2000 [00:02<00:00, 700.58it/s]

# %%
# Plotting the results
plt.plot([np.sum(matrix.shape) for matrix in matrices], times, marker='o')
plt.xlabel('Total number of elements')
plt.ylabel('Time taken (seconds)')
plt.title('Time Complexity of >0 + astype(int)')
plt.grid(True)
plt.show()

# %%
def measure_time(func, args):
    start_time = time.time()
    # Execute the operation
    _ = func(args, axis=0)
    end_time = time.time()
    return end_time - start_time

matrices = [np.random.rand(100, 10), np.random.rand(200, 10), np.random.rand(300, 10), np.random.rand(400, 10),np.random.rand(500, 10),np.random.rand(600, 10),np.random.rand(700, 10),np.random.rand(800, 10),np.random.rand(900, 10)]
trials = 2000
times = []
for matrix in matrices:
    temp_times = []
    for trial in tqdm(range(trials)):
        time_taken = measure_time(np.unique, matrix)
        temp_times.append(time_taken)
    times.append(np.mean(temp_times))
# Out:
# ...
# 100%|██████████| 2000/2000 [00:00<00:00, 2968.28it/s]

# %%
# Plotting the results
plt.plot([np.sum(matrix.shape) for matrix in matrices], times, marker='o')
plt.xlabel('Total number of elements')
plt.ylabel('Time taken (seconds)')
plt.title('Time Complexity of >0 + astype(int)')
plt.grid(True)
plt.show()
